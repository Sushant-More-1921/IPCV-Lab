# %%
#Image Restoration using Filters
import cv2
import matplotlib.pyplot as plt

# Read Image
img_bgr = cv2.imread('/content/drive/MyDrive/IPCV SEM 6/noisy image.png', 1)

# Display Image
plt.imshow(img_bgr)
plt.title("Original Image")
plt.axis('off')
plt.show()
